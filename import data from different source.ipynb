# %% [markdown]
# # Importing data from different source

# %%
import pandas as pd

# %%
pd.read_excel('file_example_XLS_50.xls',index_col='Id')
# Out:
#        0 First Name   Last Name  Gender        Country  Age        Date
# Id
# 1562   1      Dulce       Abril  Female  United States   32  15/10/2017
# 1582   2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016
# 2587   3     Philip        Gent    Male         France   36  21/05/2015
# 3549   4   Kathleen      Hanner  Female  United States   25  15/10/2017
# 2468   5    Nereida     Magwood  Female  United States   58  16/08/2016
# 2554   6     Gaston       Brumm    Male  United States   24  21/05/2015
# 3598   7       Etta        Hurn  Female  Great Britain   56  15/10/2017
# 2456   8    Earlean      Melgar  Female  United States   27  16/08/2016
# 6548   9   Vincenza     Weiland  Female  United States   40  21/05/2015
# 5486  10     Fallon     Winward  Female  Great Britain   28  16/08/2016
# 1258  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015
# 2579  12   Franklyn      Unknow    Male         France   38  15/10/2017
# ...

# %% [markdown]
# ### Reading text files

# %%
pd.read_csv('FlyRNAi_data_baseline_vs_EGF.txt',sep='\t') # sepetated by tab
# Out:
#                 ID  EGF_Baseline  EGF_Stimulus
# 0      FBgn0029994         -1.25         -0.27
# 1      FBgn0037191         -1.05          0.78
# 2      FBgn0036810          2.08          1.34
# 3      FBgn0033320          1.15          0.45
# 4      FBgn0051156         -1.77         -0.76
# ...            ...           ...           ...
# 11761  FBgn0026136          0.57          1.23
# 11762  FBgn0037356          1.14         -0.95
# 11763  FBgn0038214         -1.86         -0.67
# 11764  FBgn0042110          1.49          0.43
# 11765  FBgn0034202         -1.32         -0.22
#
# [11766 rows x 3 columns]

# %% [markdown]
# ## Reading JSON file

# %%
df = pd.read_json('https://microsoftedge.github.io/Demos/json-dummy-data/64KB.json')
# df[df['language'] == 'Marathi']
df
# Out:
#                        name   language                id  \
# 0             Adeel Solangi     Sindhi  V59OF92YF627HFY0
# 1             Afzal Ghaffar     Sindhi  ENTOCR13RSCLZ6KU
# 2             Aamir Solangi     Sindhi  IAKPO3R4761JDRVG
# 3             Abla Dilmurat     Uyghur  5ZVOEPMJUI4MB4EN
# 4                  Adil Eli     Uyghur  6VTI8X6LL0MMPJCC
# ..                      ...        ...               ...
# 192  Kristín Sigurðardóttir  Icelandic  ZP5TBBYX6RI2UJ31
# 193            Rohini Vasav      Hindi  UEFML43TCGS04KWM
# 194            Sunil Kapoor      Hindi  VY2A0APGVHK5NAW2
# 195          Zamokuhle Zulu    isiZulu  XU7BX2F8M5PVZ1EF
# 196           Bhupesh Menon      Hindi  0CEPNRDV98KT3ORP
#
#                                                    bio  version
# 0    Donec lobortis eleifend condimentum. Cras dict...     6.10
# 1    Aliquam sollicitudin ante ligula, eget malesua...     1.88
# 2    Vestibulum pharetra libero et velit gravida eu...     7.27
# ...

# %% [markdown]
# ## Working with SQL

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
df = pd.read_sql_query("SELECT * FROM city",conn)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13336\3653681956.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM city",conn)

# %%
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]
